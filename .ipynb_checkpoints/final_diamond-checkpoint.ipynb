# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# %%
df=pd.read_csv('diamonds.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
df=df.drop(df[ df['x']==0].index)
df=df.drop(df[ df['y']==0].index)
df=df.drop(df[ df['z']==0].index)
df.shape
# Out:
# (53920, 10)

# %%
sns.pairplot(df)

# %%
sns.regplot(data=df,x='price',y='y')
# Out:
# <AxesSubplot:xlabel='price', ylabel='y'>

# %%
sns.regplot(data=df,x='price',y='z',fit_reg=True,marker='o')
# Out:
# <AxesSubplot:xlabel='price', ylabel='z'>

# %%
sns.regplot(data=df,x='price',y='x',fit_reg=True,marker='o')
# Out:
# <AxesSubplot:xlabel='price', ylabel='x'>

# %%
sns.regplot(data=df,x='price',y='depth',fit_reg=True,marker='o')
# Out:
# <AxesSubplot:xlabel='price', ylabel='depth'>

# %%
sns.regplot(data=df,x='price',y='table',fit_reg=True,marker='o')
# Out:
# <AxesSubplot:xlabel='price', ylabel='table'>

# %%
df= df[(df['depth'] < 75)&(df['depth'] > 45)]
df= df[(df['table'] < 70)&(df['table'] > 50)]
df= df[(df['y'] < 30)]
df= df[(df['x'] < 30)]
df= df[(df['z'] < 30)&(df['z'] > 2)]
df.shape
# Out:
# (53887, 10)

# %%
ax=sns.pairplot(df, hue= "cut")

# %%
#Yay !!! data os now clean !!!

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x=df['cut'],y=df['price'])
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x=df['clarity'],y=df['price'])
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x=df['color'],y=df['price'])
# Out:
# <AxesSubplot:xlabel='color', ylabel='price'>

# %%
df_final= df.copy()
df_final=pd.get_dummies(df_final,drop_first=True)

# %%
#plt.figure(figsize=(10,4),dpi=200)
sns.barplot(x=df_final.corr()['price'].sort_values().iloc[1:-1].index,y=df_final.corr()['price'].sort_values().iloc[1:-1].values)
plt.title("Feature Correlation to Yes Churn")
plt.xticks(rotation=90);

# %%
#X,Y ,Z and Carat Show Highet Correlation to the price

# %% [markdown]
# ## MODEL BUILDING

# %%
X= df_final.drop('price',axis=1)
y=df_final['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=101)

# %%
pipepline_lr= Pipeline([('scaler',StandardScaler()),
                         ('lin_reg',LinearRegression())])


pipeline_dtr= Pipeline([('scaler',StandardScaler()),
                         ('decision_tree',DecisionTreeRegressor())])


pipeline_rf= Pipeline([('scaler',StandardScaler()),
                         ('random_forest',RandomForestRegressor())])

pipeline_KNN= Pipeline([('scaler',StandardScaler()),
                         ('KNN',KNeighborsRegressor())])

pipelines= [pipepline_lr,pipeline_dtr,pipeline_rf,pipeline_KNN]

pipe_dict={0:'LinearRegression',1:'DecissionTree',2:'RandomForest',
           3:'Kneighbors'}
                        
    
for pipe in pipelines:
    pipe.fit(X_train,y_train)
    

cv_resuls=[]

for i,model in enumerate(pipelines):
    cv_score= cross_val_score(model,X_train,y_train,
                              scoring='neg_root_mean_squared_error',
                              cv=10)
    
    cv_resuls.append(cv_score)
    print("%s: %f:" %(pipe_dict[i],cv_score.mean()) )
# Out:
# LinearRegression: -1122.897426:
# DecissionTree: -856.390251:
# RandomForest: -629.594149:
# Kneighbors: -820.741876:

# %%
#Random Forest Peformed among the validation set next we will try to firther improve Random Forest

# %%
param_grid= {'n_estimators':[1,5,10,20,40,100],'max_depth':[3,4,5,6]}

grid_model=RandomForestRegressor()

grid= GridSearchCV(grid_model,param_grid,scoring='neg_root_mean_squared_error')

pipe_final= Pipeline([('scaler',StandardScaler()),
                         ('grid',grid)])

pipe_final.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('grid',
#                  GridSearchCV(estimator=RandomForestRegressor(),
#                               param_grid={'max_depth': [3, 4, 5, 6],
#                                           'n_estimators': [1, 5, 10, 20, 40,
#                                                            100]},
#                               scoring='neg_root_mean_squared_error'))])

# %%
grid.best_score_
# Out:
# -1072.57925283055

# %%
grid.best_estimator_
# Out:
# RandomForestRegressor(max_depth=6)

# %%
grid.best_params_
# Out:
# {'max_depth': 6, 'n_estimators': 100}

# %%
#Our Grid model didnot fit quite expected hence we go with our pipeline_rf as our final model and predict on test data

# %%
pred= pipeline_rf.predict(X_test)

print("MAE:",metrics.mean_absolute_error(y_test, pred))
print("MSE:",metrics.mean_squared_error(y_test, pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, pred)))
print("R^2:", metrics.r2_score(y_test,pred))
print("Adjusted R^2:",1 - (1-metrics.r2_score(y_test, pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
# Out:
# MAE: 296.21636938560914
# MSE: 401152.3619456102
# RMSE: 633.3658989443702
# R^2: 0.9748682482111969
# Adjusted R^2: 0.9747605072436027

# %%
#END
